# %%
# !git clone https://github.com/krasserm/super-resolution
# Out:
# Cloning into 'super-resolution'...
# remote: Enumerating objects: 405, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 405 (delta 9), reused 19 (delta 8), pack-reused 385
# Receiving objects: 100% (405/405), 54.27 MiB | 29.81 MiB/s, done.
# Resolving deltas: 100% (209/209), done.

# %%
# %cd /content
# Out:
# /content

# %%
# !unzip -q '/content/drive/MyDrive/BE_project/data.zip'

# %%
# %cd /content/drive/MyDrive/super-resolution
#%cd /content/super-resolution
# Out:
# /content/drive/MyDrive/super-resolution

# %%
from model.srgan import generator
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

import time
import tensorflow as tf

from model import evaluate
from model import srgan

from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import Mean
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PiecewiseConstantDecay



from model import resolve_single
from utils import load_image,plot_sample

def resolve_and_plot(lr_image_path):
    lr = load_image(lr_image_path)
    
    pre_sr = resolve_single(pre_generator, lr)
    gan_sr = resolve_single(gan_generator, lr)
    
    plt.figure(figsize=(20, 20))
    
    images = [lr, pre_sr, gan_sr]
    titles = ['LR', 'SR (PRE)', 'SR (GAN)']
    positions = [1, 3, 4]
    
    for i, (img, title, pos) in enumerate(zip(images, titles, positions)):
        plt.subplot(2, 2, pos)
        plt.imshow(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])

# %%
# from PIL import Image
  
# # Open the image by specifying the image path.
# image_path = "/content/image_872.jpg"
# image_file = Image.open(image_path)
# zat2=image_file.resize((64,64))
  
# # the default
# zat2.save("/content/zat2.jpg")

# def load_image(path):
#     image_file = Image.open(path)
#     zat2=image_file.resize((64,64))
#     return np.array(zat2)

# %%
def load_image1(path):
    image_file = Image.open(path)
    zat2=image_file.resize((64,64))
    return np.array(zat2)
model = generator()


model.load_weights('/content/drive/MyDrive/gan_generator.h5')

lr = load_image1('/content/drive/MyDrive/super-resolution/dataset/data/image_69.png')
sr = resolve_single(model, lr)

plot_sample(lr, sr)

# %%
from model.srgan import generator

import time
import tensorflow as tf

from model import evaluate
from model import srgan

from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import Mean
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PiecewiseConstantDecay



from model import resolve_single
from utils import load_image,plot_sample
import matplotlib.pyplot as plt
def resolve_and_plot1(lr_image_path):
    lr = load_image1(lr_image_path)
    
    #pre_sr = resolve_single(model, lr)
    pre_sr=Image.open(lr_image_path)
    gan_sr = resolve_single(model, lr)
    
    plt.figure(figsize=(20, 20))
    
    images = [lr, pre_sr, gan_sr]
    # titles = ['LR', 'SR (PRE)', 'SR (GAN)']
    titles = ['LR', 'Normal', 'SR (GAN)']
    positions = [1, 2, 3]
    
    for i, (img, title, pos) in enumerate(zip(images, titles, positions)):
        plt.subplot(1, 3, pos)
        plt.imshow(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])


# model = generator()


# model.load_weights('/content/drive/MyDrive/gan_generator.h5')

# lr = load_image('/content/dataset/data/image_2.png')
# sr = resolve_single(model, lr)

# plot_sample(lr, sr)

# %%
resolve_and_plot1('/content/drive/MyDrive/super-resolution/dataset/data/image_170.png')

# %%
resolve_and_plot1('/content/drive/MyDrive/super-resolution/dataset/data/image_100.png')

# %%
resolve_and_plot1('/content/drive/MyDrive/super-resolution/dataset/data/image_1009.png')

# %%
resolve_and_plot1('/content/drive/MyDrive/super-resolution/dataset/data/image_1013.png')

# %%
resolve_and_plot1('/content/drive/MyDrive/super-resolution/dataset/data/image_1019.png')

# %%
resolve_and_plot1('/content/drive/MyDrive/super-resolution/dataset/data/image_1021.png')

# %%
def resolve_and_plot2(lr_image_path):
    lr = load_image1(lr_image_path)
    
    #pre_sr = resolve_single(model, lr)
    pre_sr=Image.open(lr_image_path)
    gan_sr = resolve_single(model, lr)
    
    plt.figure(figsize=(20, 20))
    
    images = [lr, pre_sr, gan_sr]
    # titles = ['LR', 'SR (PRE)', 'SR (GAN)']
    titles = ['LR', 'Normal', 'SR (GAN)']
    positions = [1, 2, 3]
    
    for i, (img, title, pos) in enumerate(zip(images, titles, positions)):
        plt.subplot(1, 3, pos)
        plt.imshow(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])

# %%
resolve_and_plot2('/content/drive/MyDrive/super-resolution/dataset/data/image_69.png')

# %%
# Out:
# /content/drive/MyDrive/SRGAN

# %%
# %cd /content/drive/MyDrive/SRGAN/
from tensorflow import keras
from model import FastSRGAN
args={'hr_size':264,'lr':64}
model1=FastSRGAN()

model1=keras.models.load_model('/content/drive/MyDrive/SRGAN/models/generator.h5')
# Out:
# /content/drive/MyDrive/SRGAN
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image


def load_image(path):
    image_file = Image.open(path)
    zat2=image_file.resize((64,64))
    return np.array(zat2)


def plot_sample(lr, sr):
    plt.figure(figsize=(20, 10))

    images = [lr, sr]
    titles = ['LR', f'SR (x{sr.shape[0] // lr.shape[0]})']

    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, 2, i+1)
        plt.imshow(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
import numpy as np
import tensorflow as tf


DIV2K_RGB_MEAN = np.array([0.4488, 0.4371, 0.4040]) * 255


def resolve_single(model, lr):
    return resolve(model, tf.expand_dims(lr, axis=0))[0]


def resolve(model, lr_batch):
    lr_batch = tf.cast(lr_batch, tf.float32)
    sr_batch = model(lr_batch)
    sr_batch = tf.clip_by_value(sr_batch, 0, 255)
    sr_batch = tf.round(sr_batch)
    sr_batch = tf.cast(sr_batch, tf.uint8)
    return sr_batch

import numpy as np
import tensorflow as tf


DIV2K_RGB_MEAN = np.array([0.4488, 0.4371, 0.4040]) * 255


def resolve_single(model, lr):
    return resolve(model, tf.expand_dims(lr, axis=0))[0]
def load_image1(path):
    image_file = Image.open(path)
    zat2=image_file.resize((64,64))
    return np.array(zat2)







def resolve(model, lr_batch):
    lr_batch = tf.cast(lr_batch, tf.float32)
    sr_batch = model(lr_batch)
    sr_batch = tf.clip_by_value(sr_batch, 0, 255)
    sr_batch = tf.round(sr_batch)
    sr_batch = tf.cast(sr_batch, tf.uint8)
    return sr_batch

# %%
def resolve_and_plot2(lr_image_path):
    lr = load_image1(lr_image_path)
    
    #pre_sr = resolve_single(model, lr)
    pre_sr=Image.open(lr_image_path)
    gan_sr = resolve_single(model1, lr)
    
    plt.figure(figsize=(20, 20))
    
    images = [lr, pre_sr, gan_sr]
    # titles = ['LR', 'SR (PRE)', 'SR (GAN)']
    titles = ['LR', 'Normal', 'SR (GAN)']
    positions = [1, 2, 3]
    
    for i, (img, title, pos) in enumerate(zip(images, titles, positions)):
        plt.subplot(1, 3, pos)
        plt.imshow(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])

# %%
resolve_and_plot2('/content/drive/MyDrive/super-resolution/dataset/data/image_69.png')

# %%
lr = load_image1(lr_image_path)
gan_sr=model1.generator(lr)
